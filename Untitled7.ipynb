# %%
# !python main.py
# Out:
# https://boydkane.com/essays/boss
# Traceback (most recent call last):
#   File "/teamspace/studios/this_studio/main.py", line 10, in <module>
#     title, description, content = scraper.fetchPage(pageURL)
#   File "/teamspace/studios/this_studio/scraper.py", line 36, in fetchPage
#     driver = webdriver.Chrome(options=options)
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/selenium/webdriver/chrome/webdriver.py", line 45, in __init__
#     super().__init__(
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/selenium/webdriver/chromium/webdriver.py", line 50, in __init__
#     self.service.start()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/selenium/webdriver/common/service.py", line 102, in start
#     self.assert_process_still_running()
#   File "/home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/selenium/webdriver/common/service.py", line 115, in assert_process_still_running
# ...
